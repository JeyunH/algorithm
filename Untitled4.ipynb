# %%
# !pip install pandas

# %%
import pandas as pd

pd.DataFrame({"학생이름" : ["김철수","이영희","박지민"],
             "나이" : [25,30,22],
             "키" : [175,162,168]
             })
# Out:
#   학생이름  나이    키
# 0  김철수  25  175
# 1  이영희  30  162
# 2  박지민  22  168

# %%
df = pd.read_csv('cafe_1.csv')
df.head()
# Out:
#          date day_of_week  americano  ...  ny_cheese_cake  carrot_cake  tiramisu
# 0  2025-01-01           수      218.0  ...               8            7         9
# 1  2025-01-02           목      222.0  ...              31            0         6
# 2  2025-01-03           금      215.0  ...               0            8        12
# 3  2025-01-04           토      313.0  ...              66           78        47
# 4  2025-01-05           일      311.0  ...              35           40        17
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            60 non-null     object
#  1   day_of_week     60 non-null     object
#  2   americano       58 non-null     float64
#  3   cafe_latte      59 non-null     float64
#  4   cappuccino      60 non-null     int64
#  5   lemon_ade       59 non-null     float64
#  6   grapefruit_ade  60 non-null     int64
#  7   herbal_tea      60 non-null     int64
#  8   chocolate_cake  60 non-null     int64
#  9   ny_cheese_cake  60 non-null     int64
#  10  carrot_cake     60 non-null     int64
#  11  tiramisu        60 non-null     int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 5.8+ KB

# %%
df.describe()
# Out:
#         americano  cafe_latte  ...  carrot_cake    tiramisu
# count   58.000000   59.000000  ...    60.000000   60.000000
# mean   250.620690   80.084746  ...    24.516667   24.850000
# std     66.880052   22.978467  ...    18.587851   20.988152
# min     20.000000   30.000000  ...     0.000000    0.000000
# 25%    218.000000   66.500000  ...     8.000000    9.750000
# 50%    222.500000   77.000000  ...    23.500000   21.000000
# 75%    309.000000   91.000000  ...    38.250000   37.500000
# max    500.000000  144.000000  ...    78.000000  100.000000
#
# [8 rows x 10 columns]

# %%
print(df.shape)
print(df.columns)
# Out:
# (60, 12)
# Index(['date', 'day_of_week', 'americano', 'cafe_latte', 'cappuccino',
#        'lemon_ade', 'grapefruit_ade', 'herbal_tea', 'chocolate_cake',
#        'ny_cheese_cake', 'carrot_cake', 'tiramisu'],
#       dtype='object')

# %%
df[(df["americano"] > 350) & (df["cappuccino"] > 80)]
# Out:
#           date day_of_week  americano  ...  ny_cheese_cake  carrot_cake  tiramisu
# 14  2025-01-15           수      450.0  ...               9           37         9
#
# [1 rows x 12 columns]

# %%
df.groupby("day_of_week").mean(numeric_only=True).sort_values(by="day_of_week",ascending=True)
# Out:
#               americano  cafe_latte  ...  carrot_cake   tiramisu
# day_of_week                          ...
# 금            222.500000   75.444444  ...    24.444444  22.111111
# 목            217.777778   79.000000  ...    27.777778  30.555556
# 수            277.666667   62.333333  ...    15.444444  10.777778
# 월            222.142857   66.375000  ...    15.875000  16.500000
# 일            273.250000  100.250000  ...    28.625000  32.375000
# 토            314.555556  109.250000  ...    36.222222  37.222222
# 화            215.625000   70.875000  ...    22.500000  24.250000
#
# [7 rows x 10 columns]

# %%
# 리스트릴 이용한 시리즈(단일 열)<판다스>
ages = pd.Series([25,30,22])
print(ages)
# Out:
# 0    25
# 1    30
# 2    22
# dtype: int64

# %%
# 리스트를 이용한 데이터프레임<판다스>
import pandas as pd
data = [
        ["김철수", 25, 175],
        ["이영희", 30, 162],
        ["박지민", 22, 168]
        ]
df = pd.DataFrame(data, columns=["이름","나이","키"])
df
# Out:
#     이름  나이    키
# 0  김철수  25  175
# 1  이영희  30  162
# 2  박지민  22  168

# %%
# 딕셔너리를 이용한 데이터프레임<판다스>
data = {
    "학생이름" : ["김철수", "이영희", "박지민"],
    "나이" : [25,30,22],
    "키" : [175,162,168]
}
df = pd.DataFrame(data)
df
# Out:
#   학생이름  나이    키
# 0  김철수  25  175
# 1  이영희  30  162
# 2  박지민  22  168

# %%
# 하나의 열 선택
data = {
    "이름" : ["김철수", "이영희", "박지민", "김은혜"],
    "성별" : ["남자","여자","남자","여자"],
    "나이" : [25,30,22,29],
    "키" : [175,162,168,160],
    "점수" : [92,75,81,90]
}
df = pd.DataFrame(data)

name_column = df['이름']
name_column
# Out:
# 0    김철수
# 1    이영희
# 2    박지민
# 3    김은혜
# Name: 이름, dtype: object

# %%
# 두 개 이상의 열 선택
name_gender = df[['이름', '성별']]
# Out:
#     이름  성별
# 0  김철수  남자
# 1  이영희  여자
# 2  박지민  남자
# 3  김은혜  여자

# %%
# 특정 열에서 특정 값만 보고 싶을 때(인덱스 방법)
df["점수"][0]
# Out:
# np.int64(92)
